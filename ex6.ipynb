# %%
class Passenger:
    def __init__(self, name, lug_weight, age):
        self.name = name
        self.luggage_weight = lug_weight
        self.age = age
        

class Car:
    def __init__(self, free_space, lug_weight_limit):
        self.free_space = free_space
        self.lug_weight_limit = lug_weight_limit
        self.passenger_list = []
        self.luggage_space = []
        

    def add_passenger(self, person):
        if   self.free_space > 0 and self.lug_weight_limit - sum(self.luggage_space) >= person.luggage_weight:
            self.passenger_list.append(person)
            self.free_space -= 1
            self.luggage_space.append(person.luggage_weight)
        else:
            print('მანქანა სავსეა')


    def count_average(self):
        return sum(self.luggage_space)/len(self.luggage_space)

        



p1 = Passenger('david', 21, 29)
p2 = Passenger('dato', 26, 25)
p3 = Passenger('angela', 19, 23)
p4 = Passenger('niniko', 15, 21)
p5 = Passenger('nika', 15, 21)
p6 = Passenger('eva', 21, 21)
p7 = Passenger('taso', 10, 21)
p8 = Passenger('saba', 40, 21)
p9 = Passenger('nino', 50, 21)
p10 = Passenger('mako', 30, 21)
p11 = Passenger('tedo', 14, 21)
p12 = Passenger('mari', 26, 21)
p13 = Passenger('ani', 32, 21)
p14 = Passenger('tata', 18, 21)
p15 = Passenger('sandro', 13, 21)
p16 = Passenger('lasha', 17, 21)
p17 = Passenger('lamzira', 167, 21)
p18 = Passenger('jumberi', 132, 21)
p19 = Passenger('xvtiso', 11, 21)
p20 = Passenger('valiko', 98, 21)


car1 = Car(5, 475)
car2 = Car(3, 50)
car3 = Car(6, 60)
car4 = Car(7, 145)
car5 = Car(8, 150)

car1.add_passenger(p1)
car1.add_passenger(p2)
car1.add_passenger(p3)
car1.add_passenger(p4)
car1.add_passenger(p5)

car2.add_passenger(p6)
car2.add_passenger(p7)


car3.add_passenger(p8)

car4.add_passenger(p9)
car4.add_passenger(p10)
car4.add_passenger(p11)
car4.add_passenger(p12)

car5.add_passenger(p13)
car5.add_passenger(p14)
car5.add_passenger(p15)
car5.add_passenger(p16)

# საშუალო წონა ბარგისთვის
weight_1=sum(car1.luggage_space)/len(car1.luggage_space)
weight_2=sum(car2.luggage_space)/len(car2.luggage_space)
weight_3=sum(car3.luggage_space)/len(car3.luggage_space)
weight_4=sum(car4.luggage_space)/len(car4.luggage_space)
weight_5=sum(car5.luggage_space)/len(car5.luggage_space)


# საშუალო ასაკის გამოთვლა

ages =[i.age for i in car1.passenger_list]
age_1=car1.average_age = sum(ages)/len(ages)
ages =[i.age for i in car2.passenger_list]
age_2=car2.average_age = sum(ages)/len(ages)
ages =[i.age for i in car3.passenger_list]
age_3=car3.average_age = sum(ages)/len(ages)
ages =[i.age for i in car4.passenger_list]
age_4=car4.average_age = sum(ages)/len(ages)
ages =[i.age for i in car5.passenger_list]
age_5=car5.average_age = sum(ages)/len(ages)

# 4 მგზავრი მანქანის გარეშე
pwc=[p17.name, p18.name, p19.name, p20.name]

# ცარიელი სივრცე მანქანაში
space_1=car1.lug_weight_limit - sum(car1.luggage_space)
space_2=car2.lug_weight_limit - sum(car2.luggage_space)
space_3=car3.lug_weight_limit - sum(car3.luggage_space)
space_4=car4.lug_weight_limit - sum(car4.luggage_space)
space_5=car5.lug_weight_limit - sum(car5.luggage_space)

# ცარიელი ადგილები მანქანაში
seat_1=car1.free_space 
seat_2=car2.free_space 
seat_3=car3.free_space 
seat_4=car4.free_space 
seat_5=car5.free_space
